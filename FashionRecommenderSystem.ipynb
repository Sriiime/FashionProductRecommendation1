# %%
import pandas as pd

# %%
df = pd.read_csv('/content/fashion_products.csv')

# %%
df.head()
# Out:
#    User ID  Product ID Product Name   Brand         Category  Price    Rating  \
# 0       19           1        Dress  Adidas    Men's Fashion     40  1.043159
# 1       97           2        Shoes     H&M  Women's Fashion     82  4.026416
# 2       25           3        Dress  Adidas  Women's Fashion     44  3.337938
# 3       57           4        Shoes    Zara    Men's Fashion     23  1.049523
# 4       79           5      T-shirt  Adidas    Men's Fashion     79  4.302773
#
#     Color Size
# 0   Black   XL
# 1   Black    L
# 2  Yellow   XL
# 3   White    S
# 4   Black    M

# %% [markdown]
# **Size of the dataframe**

# %%
df.shape
# Out:
# (1000, 9)

# %% [markdown]
# **Let us see the different type of products**

# %%
df['Product Name'].unique()
# Out:
# array(['Dress', 'Shoes', 'T-shirt', 'Jeans', 'Sweater'], dtype=object)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# **Let us see which brand is the most purchased in Men's Fashion**

# %%
# Filter data for "Dress" category
dress_df = df[df['Category'] == "Men's Fashion"]


# Group data by brand and calculate count
brand_counts = dress_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in Dress')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()


# Find maximum purchased brand
max_purchased_brand = brand_counts.index[0]
print(f"Maximum purchased brand in Dress: {max_purchased_brand}")
# Out:
# Maximum purchased brand in Dress: Zara

# %% [markdown]
# **Most purchased brand in Women's fashion**

# %%
# Filter data for "Dress" category
dress_df = df[df['Category'] == "Women's Fashion"]


# Group data by brand and calculate count
brand_counts = dress_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in Dress')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()


# Find maximum purchased brand
max_purchased_brand = brand_counts.index[0]
print(f"Maximum purchased brand in Dress: {max_purchased_brand}")
# Out:
# Maximum purchased brand in Dress: Gucci

# %% [markdown]
# **Maximum Purchased Brand in T-shirt**

# %%
# Filter data for "T-shirt" category
tshirt_df = df[df['Product Name'].str.contains('T-shirt', case=False)]


# Group data by brand and calculate count
brand_counts = tshirt_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in T-shirt')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()


# Find maximum purchased brand
max_purchased_brand = brand_counts.index[0]
print(f"Maximum purchased brand in T-shirt: {max_purchased_brand}")
# Out:
# Maximum purchased brand in T-shirt: Nike

# %% [markdown]
# **Maximum Purchased Brand in Shoes**

# %%
# Filter data for "Shoes" category
tshirt_df = df[df['Product Name'].str.contains('Shoes', case=False)]


# Group data by brand and calculate count
brand_counts = tshirt_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in Shoes')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Maximum Purchased Brand in Jeans**

# %%
# Filter data for "Jeans" category
tshirt_df = df[df['Product Name'].str.contains('Jeans', case=False)]


# Group data by brand and calculate count
brand_counts = tshirt_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in Jeans')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Maximum Purchased Brand in Sweater**

# %%
# Filter data for "Sweater" category
tshirt_df = df[df['Product Name'].str.contains('Sweater', case=False)]


# Group data by brand and calculate count
brand_counts = tshirt_df['Brand'].value_counts()


# Plot bar chart
plt.figure(figsize=(10, 6))
brand_counts.plot(kind='bar')
plt.title('Maximum Purchased Brand in Sweater')
plt.xlabel('Brand')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# **Selection of colors in different category**

# %%
import seaborn as sns

# %%
# Group data by category and color, and calculate count
color_category_counts = df.groupby(['Category', 'Color']).size().reset_index(name='Count')


# Pivot data for plotting
pivot_df = color_category_counts.pivot(index='Category', columns='Color', values='Count')


# Plot heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(pivot_df, annot=True, cmap='Blues')
plt.title('Color vs Category')
plt.xlabel('Color')
plt.ylabel('Category')
plt.show()


# Plot bar chart for each category
for category in df['Category'].unique():
    category_df = df[df['Category'] == category]
    color_counts = category_df['Color'].value_counts()

    plt.figure(figsize=(10, 6))
    color_counts.plot(kind='bar')
    plt.title(f'Color Distribution in {category}')
    plt.xlabel('Color')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# **Average price of different product**

# %%
# Group data by product name and calculate average price
avg_price_df = df.groupby('Product Name')['Price'].mean().reset_index()


# Sort data by average price in descending order
avg_price_df = avg_price_df.sort_values('Price', ascending=False)


# Plot bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Product Name', y='Price', data=avg_price_df)
plt.title('Average Price by Product Name')
plt.xlabel('Product Name')
plt.ylabel('Average Price')
plt.xticks(rotation=90)
plt.show()


# Print top 10 most expensive products
print("Top 10 Most Expensive Products:")
print(avg_price_df.head(10))


# Print top 10 least expensive products
print("\nTop 10 Least Expensive Products:")
print(avg_price_df.tail(10))
# Out:
# Top 10 Most Expensive Products:
#   Product Name      Price
# 2        Shoes  56.738739
# 4      T-shirt  56.711443
# 1        Jeans  56.696970
# 3      Sweater  54.788235
# 0        Dress  53.289773
#
# Top 10 Least Expensive Products:
#   Product Name      Price
# 2        Shoes  56.738739
# 4      T-shirt  56.711443
# 1        Jeans  56.696970
# 3      Sweater  54.788235
# 0        Dress  53.289773

# %% [markdown]
# **Top 10 Highest Rated Brands**

# %%
# Group data by brand and calculate average rating
avg_rating_df = df.groupby('Brand')['Rating'].mean().reset_index()


# Sort data by average rating in descending order
avg_rating_df = avg_rating_df.sort_values('Rating', ascending=False)


# Plot bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Brand', y='Rating', data=avg_rating_df)
plt.title('Average Rating by Brand')
plt.xlabel('Brand')
plt.ylabel('Average Rating')
plt.xticks(rotation=90)
plt.show()


# Print top 10 highest rated brands
print("Top 10 Highest Rated Brands:")
print(avg_rating_df.head(10))


# Additional analysis
# Rating distribution by brand
plt.figure(figsize=(12, 8))
sns.boxplot(x='Brand', y='Rating', data=df)
plt.title('Rating Distribution by Brand')
plt.xlabel('Brand')
plt.ylabel('Rating')
plt.xticks(rotation=90)
plt.show()
# Out:
# Top 10 Highest Rated Brands:
#     Brand    Rating
# 1   Gucci  3.162277
# 4    Zara  3.001594
# 2     H&M  2.996309
# 0  Adidas  2.942720
# 3    Nike  2.877917
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:640: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %% [markdown]
# **Most Purchased Colors by Product Name**

# %%
# Group data by product name and color, and calculate count
product_color_counts = df.groupby(['Product Name', 'Color']).size().reset_index(name='Count')


# Find most purchased color for each product
most_purchased_colors = product_color_counts.loc[product_color_counts.groupby('Product Name')['Count'].idxmax()]


# Plot bar chart
plt.figure(figsize=(12, 8))
sns.barplot(x='Product Name', y='Count', hue='Color', data=most_purchased_colors)
plt.title('Most Purchased Color by Product Name')
plt.xlabel('Product Name')
plt.ylabel('Count')
plt.xticks(rotation=90)
plt.legend(title='Color')
plt.show()


# Print most purchased colors
print("Most Purchased Colors by Product Name:")
print(most_purchased_colors)


# Additional analysis
# Top 10 products with most purchased colors
top_10_products = most_purchased_colors.nlargest(10, 'Count')
print("\nTop 10 Products with Most Purchased Colors:")
print(top_10_products)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Most Purchased Colors by Product Name:
# ...

# %% [markdown]
# **Top 10 Most Active Users**

# %%
# Count purchases by user ID
user_activity = df['User ID'].value_counts()


# Find most active user ID
most_active_user = user_activity.index[0]


# Print most active user ID and purchase count
print(f"Most Active User ID: {most_active_user}")
print(f"Purchase Count: {user_activity.max()}")


# Top 10 most active users
top_10_users = user_activity.nlargest(10)
print("\nTop 10 Most Active Users:")
print(top_10_users)


# Plot bar chart
import matplotlib.pyplot as plt
plt.figure(figsize=(10, 6))
top_10_users.plot(kind='bar')
plt.title('Top 10 Most Active Users')
plt.xlabel('User ID')
plt.ylabel('Purchase Count')
plt.show()
# Out:
# Most Active User ID: 37
# Purchase Count: 18
#
# Top 10 Most Active Users:
# User ID
# 37    18
# 65    17
# 34    16
# 89    15
# 80    15
# 46    15
# 9     15
# 61    14
# 25    14
# 77    14
# Name: count, dtype: int64

# %% [markdown]
# **Building Recommendation System**

# %%
pip install surprise
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.4/154.4 kB 2.9 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#   Created wheel for scikit-surprise: filename=scikit_surprise-1.1.4-cp310-cp310-linux_x86_64.whl size=2357264 sha256=32dd5a319081d89623156d20d72966098f01a8bfbd828ab058f0a501e67e1e04
#   Stored in directory: /root/.cache/pip/wheels/4b/3f/df/6acbf0a40397d9bf3ff97f582cc22fb9ce66adde75bc71fd54
# Successfully built scikit-surprise
# ...

# %%
from surprise import Reader, Dataset, KNNWithMeans
from surprise.model_selection import train_test_split
from surprise import accuracy

# %%
# Convert data to Surprise format
reader = Reader(rating_scale=(1, 5))
data = Dataset.load_from_df(df[['User ID', 'Product ID', 'Rating']], reader)

# %%
# Split data into training and testing sets
trainset, testset = train_test_split(data, test_size=.25)

# %%
# Build KNN-based recommender
algo = KNNWithMeans(k=50, sim_options={'name': 'pearson_baseline', 'user_based': False})

# %%
# Train algorithm
algo.fit(trainset)
# Out:
# Estimating biases using als...
# Computing the pearson_baseline similarity matrix...
# Done computing similarity matrix.

# %%
# Make predictions
predictions = algo.test(testset)

# %%
# Evaluate algorithm
accuracy.rmse(predictions)
# Out:
# RMSE: 1.1262
# 1.1262079103636262

# %%
# Function to get top N recommendations for a user
def get_top_n(user_id, n):
    inner_id = algo.trainset.to_inner_uid(user_id)
    ratings = {}

    for raw_id in algo.trainset.all_items():
        rating = algo.predict(user_id, raw_id, r_ui=0).est
        ratings[raw_id] = rating

    top_n = sorted(ratings, key=ratings.get, reverse=True)[:n]
    return top_n


# Example usage
user_id = 19
n = 5
top_products = get_top_n(user_id, n)
print(f"Top {n} recommended products for User {user_id}:")
for product in top_products:
    product_info = df.loc[df['Product ID'] == product, ['Product Name', 'Brand', 'Category', 'Price']]
    if not product_info.empty:
        print(product_info)
# Out:
# Top 5 recommended products for User 19:
#     Product Name Brand       Category  Price
# 417        Jeans  Zara  Men's Fashion     34
#     Product Name  Brand         Category  Price
# 578        Shoes  Gucci  Women's Fashion     57
#     Product Name   Brand       Category  Price
# 703      T-shirt  Adidas  Kids' Fashion     38
#     Product Name  Brand       Category  Price
# 641      T-shirt  Gucci  Kids' Fashion     22
#    Product Name Brand       Category  Price
# 36      Sweater  Zara  Kids' Fashion     48
